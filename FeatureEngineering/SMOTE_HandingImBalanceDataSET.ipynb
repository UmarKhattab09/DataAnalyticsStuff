# %% [markdown]
# <a href="https://colab.research.google.com/github/UmarKhattab09/DataAnalyticsStuff/blob/main/FeatureEngineering/SMOTE_MissingHandlingDataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### SMOTE ( SYNTHETIC MINORITY OVER SAMPLING TECHNIQUE)

# %%
from sklearn.datasets import make_classification

# %%
X,y=make_classification(n_samples=1000,n_features=2,n_clusters_per_class=1,n_redundant=0,
                         weights=[0.90],random_state=12)

# %%
import pandas as pd
df = pd.DataFrame(X,columns=["f1","f2"])
df2 = pd.DataFrame(y,columns=['Target'])

# %%
final_df = pd.concat([df,df2],axis=1)
final_df.head()
# Out:
#          f1        f2  Target
# 0 -0.762898 -0.706808       0
# 1 -1.075436 -1.051162       0
# 2 -0.610115 -0.909802       0
# 3 -2.023284 -0.428945       1
# 4 -0.812921 -1.316206       0

# %%
final_df['Target'].value_counts()
# Out:
# Target
# 0    900
# 1    100
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.scatter(final_df['f1'],final_df['f2'],c=final_df['Target'])

# %%
from imblearn.over_sampling import SMOTE

## Transform
oversample = SMOTE()
X,y=oversample.fit_resample(final_df[['f1','f2']],final_df['Target'])

# %%
X.shape,y.shape
# Out:
# ((1800, 2), (1800,))

# %%
y.value_counts()
# Out:
# Target
# 0    900
# 1    900
# Name: count, dtype: int64

# %%
df1 = pd.DataFrame(X,columns=["f1","f2"])
df2 = pd.DataFrame(y,columns=['Target'])

# %%
oversample_df = pd.concat([df1,df2],axis=1)
import matplotlib.pyplot as plt

# %%
plt.scatter(oversample_df['f1'],oversample_df['f2'],c=oversample_df['Target'])
